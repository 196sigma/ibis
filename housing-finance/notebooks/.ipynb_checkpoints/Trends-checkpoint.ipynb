# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.7.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (2.24.0)
# Requirement already satisfied: lxml in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (4.5.2)
# Requirement already satisfied: pandas>=0.25 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (1.0.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: pytz>=2017.2 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (1.18.5)
# Requirement already satisfied: six>=1.5 in /Users/reginaldedwards/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas>=0.25->pytrends) (1.15.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.7.3

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
trends = pytrends.get_historical_interest(['home depot'], 
                                 year_start=2020, 
                                 month_start=1, 
                                 day_start=1, 
                                 hour_start=0, 
                                 year_end=2020, 
                                 month_end=2, 
                                 day_end=1, 
                                 hour_end=0, 
                                 cat=0, 
                                 geo='', 
                                 gprop='', 
                                 sleep=0)
# Out:
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)

# %%
trends['home depot'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
series = trends['home depot']
result = seasonal_decompose(series, period=12, model='additive')
print(result.trend)
print(result.seasonal)
print(result.resid)
print(result.observed)
# Out:
# date
# 2020-01-01 00:00:00   NaN
# 2020-01-01 01:00:00   NaN
# 2020-01-01 02:00:00   NaN
# 2020-01-01 03:00:00   NaN
# 2020-01-01 04:00:00   NaN
#                        ..
# 2020-01-14 20:00:00   NaN
# 2020-01-14 21:00:00   NaN
# 2020-01-14 22:00:00   NaN
# 2020-01-14 23:00:00   NaN
# 2020-01-15 00:00:00   NaN
# Name: trend, Length: 338, dtype: float64
# date
# 2020-01-01 00:00:00    0.730737
# 2020-01-01 01:00:00    5.733824
# 2020-01-01 02:00:00    8.693700
# 2020-01-01 03:00:00    9.165923
# 2020-01-01 04:00:00    7.482281
#                          ...
# 2020-01-14 20:00:00   -8.763090
# 2020-01-14 21:00:00   -7.085621
# 2020-01-14 22:00:00   -3.244571
# 2020-01-14 23:00:00    0.730737
# 2020-01-15 00:00:00    5.733824
# Name: seasonal, Length: 338, dtype: float64
# date
# 2020-01-01 00:00:00   NaN
# 2020-01-01 01:00:00   NaN
# 2020-01-01 02:00:00   NaN
# 2020-01-01 03:00:00   NaN
# 2020-01-01 04:00:00   NaN
#                        ..
# 2020-01-14 20:00:00   NaN
# 2020-01-14 21:00:00   NaN
# 2020-01-14 22:00:00   NaN
# 2020-01-14 23:00:00   NaN
# 2020-01-15 00:00:00   NaN
# Name: resid, Length: 338, dtype: float64
# date
# 2020-01-01 00:00:00    72.0
# 2020-01-01 01:00:00    63.0
# 2020-01-01 02:00:00    54.0
# 2020-01-01 03:00:00     0.0
# 2020-01-01 04:00:00     0.0
#                        ...
# 2020-01-14 20:00:00    64.0
# 2020-01-14 21:00:00    67.0
# 2020-01-14 22:00:00    73.0
# 2020-01-14 23:00:00    81.0
# 2020-01-15 00:00:00    82.0
# Name: home depot, Length: 338, dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
series = trends['home depot']
result = seasonal_decompose(series, period=24, model='additive')

result.plot()
pyplot.figure(figsize=(32,16))
pyplot.show()
